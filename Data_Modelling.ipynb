# %%
import pandas as pd

# %%
#%run File_Management.ipynb

# %%
pd.set_option('display.max_rows', 500)

# %%
#Definción de variables
df_id = pd.DataFrame()
df_info = pd.DataFrame()
df_tweets = pd.DataFrame()
fact_following = pd.DataFrame()

# %%
#Lectura en ficheros de los IDS de Twitter
def readID(dataframe,file):
    dataframe = pd.read_csv(file,sep=',')
    return dataframe

following_ids=readID(df_id,'followings_id_cabify_espana_03052020.csv')
following_ids
followers_ids=readID(df_id,'followers_id_cabify_espana_03052020.csv')
followers_ids
# Out:
#                id_Follower
# 0                 40744748
# 1      1000024197245136899
# 2               4415499748
# 3      1038066738745683969
# 4       877268399138775040
# ...                    ...
# 26873            306348108
# 26874            397919847
# 26875              3054151
# 26876            356199655
# 26877             18513150
#
# [26878 rows x 1 columns]

# %%
#Lectura en ficheros de los IDS de Twitter
def readInfo(dataframe,file):
    dataframe = pd.read_csv(file,sep=',')
    return dataframe


df_following_info=readInfo(df_info,'followings_info_cabify_espana_03052020.csv')
df_following_info
df_followers_info=readInfo(df_info,'followers_info_cabify_espana_03052020.csv')
df_followers_info
# Out:
#                         id                name     screen_name  \
# 0                 40744748        Louis Layton        cabocush
# 1      1000024197245136899           jiaoziqin       jiaoziqin
# 2               4415499748     Información VTC  ConductoresVTC
# 3      1038066738745683969            Kvem Enc        KVEmEnc3
# 4       877268399138775040    Anass Abdellaoui     anassabd_75
# ...                    ...                 ...             ...
# 26605            306348108         Cárol Antón     carolcosita
# 26606            397919847  Mª Angeles Buitrón    MangiBuitron
# 26607              3054151       Joe Fernandez        fdezjose
# 26608            356199655     Juan de Antonio          jdanru
# 26609             18513150       Michael Koper    michaelkoper
#
#                 created_at        location  followers_count  friends_count  \
# 0      2009-05-17 21:50:01          Mexico              936           3573
# ...

# %%
#Lectura en ficheros de los IDS de Twitter
def readTweet(dataframe,file):
    dataframe = pd.read_csv(file,sep=',')
    return dataframe


df_tweets=readTweet(df_tweets,'info_tweets_cabify_espana_03052020.csv')
df_tweets
# Out:
#               created_at               id_str                 user  \
# 0    2020-04-24 19:04:02  1253761634637688833            219102690
# 1    2020-04-24 19:20:36  1253765804048420869            111421985
# 2    2020-04-24 20:07:28  1253777599366680578             77667023
# 3    2020-04-24 20:42:06  1253786314748629002            154429660
# 4    2020-04-24 21:33:06  1253799149218168832           3278265895
# 5    2020-04-24 22:50:19  1253818581269114880  1052921697194532864
# 6    2020-04-25 00:12:34  1253839282457935878   742865337377427456
# 7    2020-04-25 01:00:30  1253851345066627073            354352508
# 8    2020-04-25 01:18:11  1253855794145169410   746472834138935296
# 9    2020-04-25 01:32:31  1253859402173624321           2275494620
# 10   2020-04-25 03:00:30  1253881540905299968   868105258135822337
# 11   2020-04-25 03:10:49  1253884140593672193   710651893232439296
# 12   2020-04-25 08:31:32  1253964849509478402           3313541309
# ...

# %% [markdown]
#  # Formatting Data

# %%
df_following_info.columns=['id_account','name_account','screen_name_account','created_at_account','location_account','followers_account','friends_account','description_account']
df_following_info
# Out:
#               id_account          name_account screen_name_account  \
# 0              714366811            Deborah Li              li_deb
# 1               39787443                cyague              cyague
# 2              194161870   Mar Gonzalez-Franco             twi_mar
# 3               48422383       Jonathan Chacón      jonathanchacon
# 4    1173984355800293377   Mobilidade Coruñesa         MobilidadeC
# ..                   ...                   ...                 ...
# 619             20332892                Lorena          LPSandroni
# 620             92256751  manuel gonzalez prol              mgprol
# 621             29163531      tisasia (🐄 en 🏰)             tisasia
# 622             16777682          JesúsEncinar        JesusEncinar
# 623             50615281       Madrid Emprende      MadridEmprende
#
#       created_at_account      location_account  followers_account  \
# 0    2012-07-24 14:20:57         Madrid, Spain                768
# ...

# %%
df_followers_info.columns=['id_account','name_account','screen_name_account','created_at_account','location_account','followers_account','friends_account','description_account']
df_followers_info
# Out:
#                 id_account        name_account screen_name_account  \
# 0                 40744748        Louis Layton            cabocush
# 1      1000024197245136899           jiaoziqin           jiaoziqin
# 2               4415499748     Información VTC      ConductoresVTC
# 3      1038066738745683969            Kvem Enc            KVEmEnc3
# 4       877268399138775040    Anass Abdellaoui         anassabd_75
# ...                    ...                 ...                 ...
# 26605            306348108         Cárol Antón         carolcosita
# 26606            397919847  Mª Angeles Buitrón        MangiBuitron
# 26607              3054151       Joe Fernandez            fdezjose
# 26608            356199655     Juan de Antonio              jdanru
# 26609             18513150       Michael Koper        michaelkoper
#
#         created_at_account location_account  followers_account  \
# 0      2009-05-17 21:50:01           Mexico                936
# ...

# %%
df_tweets.columns=['created_at_tweet','id_str','id_account','text']
df_tweets
# Out:
#         created_at_tweet               id_str           id_account  \
# 0    2020-04-24 19:04:02  1253761634637688833            219102690
# 1    2020-04-24 19:20:36  1253765804048420869            111421985
# 2    2020-04-24 20:07:28  1253777599366680578             77667023
# 3    2020-04-24 20:42:06  1253786314748629002            154429660
# 4    2020-04-24 21:33:06  1253799149218168832           3278265895
# 5    2020-04-24 22:50:19  1253818581269114880  1052921697194532864
# 6    2020-04-25 00:12:34  1253839282457935878   742865337377427456
# 7    2020-04-25 01:00:30  1253851345066627073            354352508
# 8    2020-04-25 01:18:11  1253855794145169410   746472834138935296
# 9    2020-04-25 01:32:31  1253859402173624321           2275494620
# 10   2020-04-25 03:00:30  1253881540905299968   868105258135822337
# 11   2020-04-25 03:10:49  1253884140593672193   710651893232439296
# 12   2020-04-25 08:31:32  1253964849509478402           3313541309
# ...

# %%
df_followers_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26610 entries, 0 to 26609
# Data columns (total 8 columns):
# id_account             26610 non-null int64
# name_account           26607 non-null object
# screen_name_account    26610 non-null object
# created_at_account     26610 non-null object
# location_account       17362 non-null object
# followers_account      26610 non-null int64
# friends_account        26610 non-null int64
# description_account    18027 non-null object
# dtypes: int64(3), object(5)
# memory usage: 1.6+ MB

# %%
df_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 4 columns):
# created_at_tweet    33 non-null object
# id_str              33 non-null int64
# id_account          33 non-null int64
# text                33 non-null object
# dtypes: int64(2), object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# # Modelling Data

# %%
#Cruce de tablas para construir el tablón final con la información

fact_following=pd.merge(df_following_info, df_tweets,on=['id_account'],how='inner')
fact_following
# Out:
# Empty DataFrame
# Columns: [id_account, name_account, screen_name_account, created_at_account, location_account, followers_account, friends_account, description_account, created_at_tweet, id_str, text]
# Index: []

# %%
#Cruce de tablas para construir el tablón final con la información

fact_followers=pd.merge(df_followers_info, df_tweets,on=['id_account'],how='inner')
fact_followers
# Out:
#             id_account                name_account screen_name_account  \
# 0  1235628155760709633                Bender Green        bender_green
# 1           2719496265         #TaxistaActivista🔻🐝         TitoEliteTx
# 2            221536138                   taxijerez           taxijerez
# 3            126755678                  Tito Bluni             norbero
# 4   931961401828102144  El correo amarillo del zar      CorreoAmarillo
# 5            208208406            Juanca en La Paz           juanca_JB
#
#     created_at_account       location_account  followers_account  \
# 0  2020-03-05 18:08:32                    NaN                 50
# 1  2014-07-21 06:42:14  Barcelona, Catalunya                7337
# 2  2010-11-30 22:51:27           Cadiz, Spain                194
# 3  2010-03-26 22:13:10                 MADRID                198
# 4  2017-11-18 19:04:48                    NaN                 40
# 5  2010-10-26 21:17:25           Úbeda-Madrid                153
#
# ...

# %%
fact_following.sort_values(by=['id_account','created_at_tweet'])
# Out:
# Empty DataFrame
# Columns: [id_account, name_account, screen_name_account, created_at_account, location_account, followers_account, friends_account, description_account, created_at_tweet, id_str, text]
# Index: []

# %%
fact_followers.sort_values(by=['id_account','created_at_tweet'])
# Out:
#             id_account                name_account screen_name_account  \
# 3            126755678                  Tito Bluni             norbero
# 5            208208406            Juanca en La Paz           juanca_JB
# 2            221536138                   taxijerez           taxijerez
# 1           2719496265         #TaxistaActivista🔻🐝         TitoEliteTx
# 4   931961401828102144  El correo amarillo del zar      CorreoAmarillo
# 0  1235628155760709633                Bender Green        bender_green
#
#     created_at_account       location_account  followers_account  \
# 3  2010-03-26 22:13:10                 MADRID                198
# 5  2010-10-26 21:17:25           Úbeda-Madrid                153
# 2  2010-11-30 22:51:27           Cadiz, Spain                194
# 1  2014-07-21 06:42:14  Barcelona, Catalunya                7337
# 4  2017-11-18 19:04:48                    NaN                 40
# 0  2020-03-05 18:08:32                    NaN                 50
#
# ...
